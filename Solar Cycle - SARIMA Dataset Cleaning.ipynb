# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

# %%
one = pd.read_csv('/home/cyrus/Documents/Solar/1.csv')

# %%
one
# Out:
#        Unnamed: 0  Year  DOY   MST  Global PSP [W/m^2]  Direct NIP [W/m^2]  \
# 0              60  1981  196   100              -99999              -99999
# 1              60  1981  196   200              -99999              -99999
# 2              60  1981  196   300              -99999              -99999
# 3              60  1981  196   400              -99999              -99999
# 4              60  1981  196   500              -99999              -99999
# ...           ...   ...  ...   ...                 ...                 ...
# 15595          60  1983  181  2000                   5                   0
# 15596          60  1983  181  2100                  -4                   0
# 15597          60  1983  181  2200                  -4                   0
# 15598          60  1983  181  2300                  -3                   0
# 15599          60  1983  181  2400                  -2                   0
#
#        Reflected PSP [W/m^2]  Global 40-South PSP [W/m^2]  \
# ...

# %%
two = pd.read_csv('/home/cyrus/Documents/Solar/2.csv')
two['time'] = pd.to_datetime(two['DATE (MM/DD/YYYY)'] + ' ' +two['MST'])

# %%
two
# Out:
#      DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Direct NIP [W/m^2]  \
# 0           10/25/1984  04:00              -99999              -99999
# 1           10/25/1984  05:00              -99999              -99999
# 2           10/25/1984  06:00              -99999              -99999
# 3           10/25/1984  07:00              -99999              -99999
# 4           10/25/1984  08:00              -99999              -99999
# ...                ...    ...                 ...                 ...
# 2613          4/7/1985  16:00                 531                 802
# 2614          4/7/1985  17:00                 333                 691
# 2615          4/7/1985  18:00                 130                 413
# 2616          4/7/1985  19:00                   6                  11
# 2617          4/7/1985  20:00                   0                   0
#
#       Reflected PSP [W/m^2]                time
# 0                    -99999 1984-10-25 04:00:00
# ...

# %%
three = pd.read_csv('/home/cyrus/Documents/Solar/3.csv')
three['time'] = pd.to_datetime(three['DATE (MM/DD/YYYY)'] + ' ' +three['MST'])
idx31 = three['time'].dt.minute == 0
idx32 = three['time'].dt.second == 0
three = three[idx31 & idx32]

# %%
four = pd.read_csv('/home/cyrus/Documents/Solar/4.csv')
four['time'] = pd.to_datetime(four['DATE (MM/DD/YYYY)'] + ' ' +four['MST'])
idx41 = four['time'].dt.minute == 0
idx42 = four['time'].dt.second == 0
four = four[idx41 & idx42]

# %%
five = pd.read_csv('/home/cyrus/Documents/Solar/5.csv')
five['time'] = pd.to_datetime(five['DATE (MM/DD/YYYY)'] + ' ' +five['MST'])
idx51 = five['time'].dt.minute == 0
idx52 = five['time'].dt.second == 0
five = five[idx51 & idx52]

# %%
six = pd.read_csv('/home/cyrus/Documents/Solar/6.csv')
six['time'] = pd.to_datetime(six['DATE (MM/DD/YYYY)'] + ' ' +six['MST'])
idx61 = six['time'].dt.minute == 0
idx62 = six['time'].dt.second == 0
six = six[idx61 & idx62]

# %%
seven = pd.read_csv('/home/cyrus/Documents/Solar/7.csv')
seven['time'] = pd.to_datetime(seven['DATE (MM/DD/YYYY)'] + ' ' +seven['MST'])
idx71 = seven['time'].dt.minute == 0
idx72 = seven['time'].dt.second == 0
seven = seven[idx71 & idx72]

# %%
eight = pd.read_csv('/home/cyrus/Documents/Solar/8.csv')
eight['time'] = pd.to_datetime(eight['DATE (MM/DD/YYYY)'] + ' ' +eight['MST'])
idx81 = eight['time'].dt.minute == 0
idx82 = eight['time'].dt.second == 0
eight = eight[idx81 & idx82]

# %%
nine = pd.read_csv('/home/cyrus/Documents/Solar/9.csv')
nine['time'] = pd.to_datetime(nine['DATE (MM/DD/YYYY)'] + ' ' +nine['MST'])
idx91 = nine['time'].dt.minute == 0
idx92 = nine['time'].dt.second == 0
nine = nine[idx91 & idx92]

# %%
ten = pd.read_csv('/home/cyrus/Documents/Solar/10.csv')
ten['time'] = pd.to_datetime(ten['DATE (MM/DD/YYYY)'] + ' ' +ten['MST'])
idx101 = ten['time'].dt.minute == 0
idx102 = ten['time'].dt.second == 0
ten = ten[idx101 & idx102]

# %%
eleven = pd.read_csv('/home/cyrus/Documents/Solar/11.csv')
eleven['time'] = pd.to_datetime(eleven['DATE (MM/DD/YYYY)'] + ' ' +eleven['MST'])
idx111 = eleven['time'].dt.minute == 0
idx112 = eleven['time'].dt.second == 0
eleven = eleven[idx111 & idx112]

# %%
twelve = pd.read_csv('/home/cyrus/Documents/Solar/12.csv')
twelve['time'] = pd.to_datetime(twelve['DATE (MM/DD/YYYY)'] + ' ' +twelve['MST'])
idx121 = twelve['time'].dt.minute == 0
idx122 = twelve['time'].dt.second == 0
twelve = twelve[idx121 & idx122]

# %%
thirteen = pd.read_csv('/home/cyrus/Documents/Solar/13.csv')
thirteen['time'] = pd.to_datetime(thirteen['DATE (MM/DD/YYYY)'] + ' ' +thirteen['MST'])
idx131 = thirteen['time'].dt.minute == 0
idx132 = thirteen['time'].dt.second == 0
thirteen = thirteen[idx131 & idx132]

# %%
fourteen = pd.read_csv('/home/cyrus/Documents/Solar/14.csv')
fourteen['time'] = pd.to_datetime(fourteen['DATE (MM/DD/YYYY)'] + ' ' +fourteen['MST'])
idx141 = fourteen['time'].dt.minute == 0
idx142 = fourteen['time'].dt.second == 0
fourteen = fourteen[idx141 & idx142]

# %%
fifteen = pd.read_csv('/home/cyrus/Documents/Solar/15.csv')
fifteen['time'] = pd.to_datetime(fifteen['DATE (MM/DD/YYYY)'] + ' ' +fifteen['MST'])
idx151 = fifteen['time'].dt.minute == 0
idx152 = fifteen['time'].dt.second == 0
fifteen = fifteen[idx151 & idx152]

# %%
sixteen = pd.read_csv('/home/cyrus/Documents/Solar/16.csv')
sixteen['time'] = pd.to_datetime(sixteen['DATE (MM/DD/YYYY)'] + ' ' +sixteen['MST'])
idx161 = sixteen['time'].dt.minute == 0
idx162 = sixteen['time'].dt.second == 0
sixteen = sixteen[idx161 & idx162]

# %%
seventeen = pd.read_csv('/home/cyrus/Documents/Solar/17.csv')
seventeen['time'] = pd.to_datetime(seventeen['DATE (MM/DD/YYYY)'] + ' ' +seventeen['MST'])
idx171 = seventeen['time'].dt.minute == 0
idx172 = seventeen['time'].dt.second == 0
seventeen = seventeen[idx171 & idx172]

# %%
eighteen = pd.read_csv('/home/cyrus/Documents/Solar/18.csv')
eighteen['time'] = pd.to_datetime(eighteen['DATE (MM/DD/YYYY)'] + ' ' +eighteen['MST'])
idx181 = eighteen['time'].dt.minute == 0
idx182 = eighteen['time'].dt.second == 0
eighteen = eighteen[idx181 & idx182]

# %%
nineteen = pd.read_csv('/home/cyrus/Documents/Solar/19.csv')
nineteen['time'] = pd.to_datetime(nineteen['DATE (MM/DD/YYYY)'] + ' ' +nineteen['MST'])
idx191 = nineteen['time'].dt.minute == 0
idx192 = nineteen['time'].dt.second == 0
nineteen = nineteen[idx191 & idx192]

# %%
two
# Out:
#      DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Direct NIP [W/m^2]  \
# 0           10/25/1984  04:00              -99999              -99999
# 1           10/25/1984  05:00              -99999              -99999
# 2           10/25/1984  06:00              -99999              -99999
# 3           10/25/1984  07:00              -99999              -99999
# 4           10/25/1984  08:00              -99999              -99999
# ...                ...    ...                 ...                 ...
# 2613          4/7/1985  16:00                 531                 802
# 2614          4/7/1985  17:00                 333                 691
# 2615          4/7/1985  18:00                 130                 413
# 2616          4/7/1985  19:00                   6                  11
# 2617          4/7/1985  20:00                   0                   0
#
#       Reflected PSP [W/m^2]                time
# 0                    -99999 1984-10-25 04:00:00
# ...

# %%
three
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Direct NIP [W/m^2]  \
# 1               4/8/1985  08:00              410.18              159.61
# 13              4/8/1985  09:00              437.61              148.21
# 25              4/8/1985  10:00              518.11              288.92
# 37              4/8/1985  11:00              830.73              697.12
# 49              4/8/1985  12:00              670.80              277.14
# ...                  ...    ...                 ...                 ...
# 191412         2/29/1988  08:00              223.35              792.59
# 191424         2/29/1988  09:00              407.92              858.54
# 191436         2/29/1988  10:00              556.51              779.49
# 191448         2/29/1988  11:00              681.45              955.16
# 191460         2/29/1988  12:00              749.30             1038.90
#
#         Reflected PSP [W/m^2]                time
# 1                  -99999.000 1985-04-08 08:00:00
# ...

# %%
four
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Direct NIP [W/m^2]  \
# 0              9/14/1989  04:00             -3.5809            -0.44763
# 12             9/14/1989  05:00             -4.0973            -0.52756
# 24             9/14/1989  06:00             21.8590           314.93000
# 36             9/14/1989  07:00            201.8000           783.46000
# 48             9/14/1989  08:00            415.5800           943.99000
# ...                  ...    ...                 ...                 ...
# 280129        10/13/1993  16:00            132.3800           116.76000
# 280141        10/13/1993  17:00             20.4280            -0.74536
# 280153        10/13/1993  18:00             -2.1530            -0.61044
# 280165        10/13/1993  19:00             -1.9694             0.21847
# 280177        10/13/1993  20:00             -3.6050            -0.55904
#
#         Reflected PSP [W/m^2]                time
# 0                     0.00000 1989-09-14 04:00:00
# ...

# %%
five
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Direct NIP [W/m^2]  \
# 0             10/13/1993  04:00             -2.4206            -0.04499
# 12            10/13/1993  05:00             -3.0995            -0.77129
# 24            10/13/1993  06:00             -1.3244            -0.64274
# 36            10/13/1993  07:00            107.6600           534.74000
# 48            10/13/1993  08:00            260.0400           498.28000
# ...                  ...    ...                 ...                 ...
# 279379        10/13/1997  16:00            251.9100           808.39000
# 279391        10/13/1997  17:00             26.1860           191.22000
# 279403        10/13/1997  18:00             -3.9803            -0.29577
# 279415        10/13/1997  19:00             -3.9247            -0.10288
# 279427        10/13/1997  20:00             -2.4607             0.55301
#
#         Reflected PSP [W/m^2]                time
# 0                     0.94504 1993-10-13 04:00:00
# ...

# %%
six
# Out:
#       DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Direct NIP [W/m^2]  \
# 0            10/13/1997  04:00             -2.8400            -1.16420
# 12           10/13/1997  05:00             -2.7510            -0.18653
# 24           10/13/1997  06:00             -3.8981            -0.79114
# 36           10/13/1997  07:00            113.1600           635.25000
# 48           10/13/1997  08:00            303.5700           827.12000
# ...                 ...    ...                 ...                 ...
# 87960         1/11/1999  16:00            153.5700           451.32000
# 87972         1/11/1999  17:00              5.0708            -1.22150
# 87984         1/11/1999  18:00             -3.6514             0.09001
# 87996         1/11/1999  19:00             -3.9130            -0.77791
# 88008         1/11/1999  20:00             -2.7942             0.03857
#
#        Reflected PSP [W/m^2]                time
# 0                    0.12955 1997-10-13 04:00:00
# ...

# %%
seven
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Reflected PSP [W/m^2]  \
# 0              1/13/1999  04:00           -3.522300                0.80247
# 60             1/13/1999  05:00           -1.761200                1.49670
# 120            1/13/1999  06:00            0.272180               -1.77660
# 180            1/13/1999  07:00           -0.064042               -0.73900
# 240            1/13/1999  08:00            8.901800               -1.45930
# ...                  ...    ...                 ...                    ...
# 542928         7/31/2000  04:00           -3.657600               -0.73070
# 542988         7/31/2000  05:00           -0.420630               -0.56034
# 543048         7/31/2000  06:00          123.470000               39.18400
# 543108         7/31/2000  07:00          326.270000               79.72200
# 543168         7/31/2000  08:00          533.020000              110.71000
#
#         Global LI-200 [W/m^2]                time
# ...

# %%
eight
# Out:
#       DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Direct NIP [W/m^2]  \
# 58             8/1/2000  06:00               90.88           221.29000
# 118            8/1/2000  07:00              271.71           395.62000
# 178            8/1/2000  08:00              446.14           516.39000
# 238            8/1/2000  09:00              636.25           595.55000
# 298            8/1/2000  10:00              795.10           612.82000
# ...                 ...    ...                 ...                 ...
# 67893        10/31/2000  12:00               58.02             0.05876
# 67953        10/31/2000  13:00               15.71            -0.55821
# 68013        10/31/2000  14:00               67.66            -0.11752
# 68073        10/31/2000  15:00              189.52             1.71870
# 68133        10/31/2000  16:00               21.59            -1.05400
#
#                      time
# 58    2000-08-01 06:00:00
# 118   2000-08-01 07:00:00
# 178   2000-08-01 08:00:00
# ...

# %%
nine
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Global LI-200 #1 [W/m^2]  \
# 0              11/1/2000  04:00            -1.61240                  -0.12385
# 60             11/1/2000  05:00            -1.24910                   0.04335
# 120            11/1/2000  06:00            -1.41740                   0.01239
# 180            11/1/2000  07:00            33.40800                  36.58000
# 240            11/1/2000  08:00           154.24000                 160.44000
# ...                  ...    ...                 ...                       ...
# 264995          8/3/2001  16:00           467.32000                 468.90000
# 265055          8/3/2001  17:00            82.65800                  74.91700
# 265115          8/3/2001  18:00           108.80000                 110.93000
# 265175          8/3/2001  19:00            -0.67661                   3.70890
# 265235          8/3/2001  20:00            -3.29160                   0.00000
#
# ...

# %%
ten
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Global LI-200 #1 [W/m^2]  \
# 55              8/4/2001  06:00             119.530                   119.500
# 115             8/4/2001  07:00             323.950                   303.150
# 175             8/4/2001  08:00             522.540                   503.090
# 235             8/4/2001  09:00             705.990                   678.940
# 295             8/4/2001  10:00             860.270                   826.980
# ...                  ...    ...                 ...                       ...
# 632975        12/31/2003  12:00             360.640                   363.980
# 633035        12/31/2003  13:00             304.960                   306.270
# 633095        12/31/2003  14:00             275.170                   279.120
# 633155        12/31/2003  15:00             184.850                   196.200
# 633215        12/31/2003  16:00              68.816                    96.224
#
# ...

# %%
eleven
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Global LI-200 #1 [W/m^2]  \
# 36              1/1/2004  08:00              86.069                    88.208
# 96              1/1/2004  09:00             171.260                   170.990
# 156             1/1/2004  10:00             256.360                   248.460
# 216             1/1/2004  11:00             555.760                   570.590
# 276             1/1/2004  12:00             531.370                   545.810
# ...                  ...    ...                 ...                       ...
# 531827        12/31/2005  12:00             494.500                   531.420
# 531887        12/31/2005  13:00             146.150                   147.480
# 531947        12/31/2005  14:00             362.590                   377.300
# 532007        12/31/2005  15:00             209.330                   240.580
# 532067        12/31/2005  16:00              65.122                    82.136
#
# ...

# %%
twelve
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Global LI-200 [W/m^2]  \
# 35              1/1/2006  08:00              32.346                 32.960
# 95              1/1/2006  09:00             221.340                237.660
# 155             1/1/2006  10:00             440.190                477.540
# 215             1/1/2006  11:00             468.990                497.060
# 275             1/1/2006  12:00             498.610                529.830
# ...                  ...    ...                 ...                    ...
# 719358         8/31/2008  14:00             204.980                199.620
# 719418         8/31/2008  15:00             218.520                228.560
# 719478         8/31/2008  16:00              48.678                 47.058
# 719538         8/31/2008  17:00              11.461                 10.675
# 719598         8/31/2008  18:00              56.635                 63.279
#
# ...

# %%
thirteen
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Global LI-200 [W/m^2]  \
# 28              9/1/2008  06:00             49.9660                 56.806
# 88              9/1/2008  07:00            109.4500                104.520
# 148             9/1/2008  08:00            269.3200                270.720
# 208             9/1/2008  09:00            647.5500                660.990
# 268             9/1/2008  10:00            849.8600                865.050
# ...                  ...    ...                 ...                    ...
# 451779         5/31/2010  15:00            814.3500                839.250
# 451839         5/31/2010  16:00            275.0000                282.570
# 451899         5/31/2010  17:00            310.1600                339.570
# 451959         5/31/2010  18:00             75.9360                 83.363
# 452019         5/31/2010  19:00              7.3978                 12.358
#
# ...

# %%
fourteen
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP [W/m^2]  Global LI-200 [W/m^2]  \
# 29              9/1/2010  06:00              56.293                 56.511
# 89              9/1/2010  07:00             246.390                251.700
# 149             9/1/2010  08:00             458.320                468.400
# 209             9/1/2010  09:00             427.770                428.870
# 269             9/1/2010  10:00             797.780                804.510
# ...                  ...    ...                 ...                    ...
# 452650         5/31/2012  15:00             381.910                381.740
# 452710         5/31/2012  16:00             674.460                707.320
# 452770         5/31/2012  17:00             231.210                233.300
# 452830         5/31/2012  18:00             193.820                215.200
# 452890         5/31/2012  19:00              13.435                 17.036
#
# ...

# %%
fifteen
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP (vent/cor) [W/m^2]  \
# 23              6/1/2012  05:00                        52.1136
# 83              6/1/2012  06:00                       247.6688
# 143             6/1/2012  07:00                       243.3828
# 203             6/1/2012  08:00                       574.9064
# 263             6/1/2012  09:00                       791.2830
# ...                  ...    ...                            ...
# 422541        12/31/2013  12:00                       490.0070
# 422601        12/31/2013  13:00                       458.6490
# 422661        12/31/2013  14:00                       302.7540
# 422721        12/31/2013  15:00                       308.3240
# 422781        12/31/2013  16:00                       149.2980
#
#         Global PSP (cor) [W/m^2]  Global LI-200 [W/m^2]  \
# 23                       46.5359                 39.177
# 83                      243.6737                233.800
# ...

# %%
sixteen
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP (vent/cor) [W/m^2]  \
# 23              6/1/2013  05:00                        12.8005
# 83              6/1/2013  06:00                        76.7222
# 143             6/1/2013  07:00                       206.5444
# 203             6/1/2013  08:00                       409.7354
# 263             6/1/2013  09:00                       850.9472
# ...                  ...    ...                            ...
# 422588        12/31/2014  12:00                       522.4700
# 422648        12/31/2014  13:00                       491.7890
# 422708        12/31/2014  14:00                       395.7670
# 422768        12/31/2014  15:00                       256.3510
# 422828        12/31/2014  16:00                        89.0876
#
#         Global PSP (cor) [W/m^2]  Global LI-200 [W/m^2]  \
# 23                       22.6084                13.8596
# 83                       85.1513                73.3106
# ...

# %%
seventeen
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP (vent/cor) [W/m^2]  \
# 35              1/1/2015  08:00                        76.3959
# 95              1/1/2015  09:00                       309.4560
# 155             1/1/2015  10:00                       294.1210
# 215             1/1/2015  11:00                       308.7900
# 275             1/1/2015  12:00                       234.7840
# ...                  ...    ...                            ...
# 780006        11/30/2017  12:00                       505.5260
# 780066        11/30/2017  13:00                       464.4700
# 780126        11/30/2017  14:00                       363.2300
# 780186        11/30/2017  15:00                       222.2510
# 780246        11/30/2017  16:00                        64.1528
#
#         Global LI-200 [W/m^2]  Global 40-South LI-200 [W/m^2]  \
# 35                    71.5866                         341.790
# 95                   310.9540                         797.966
# ...

# %%
eighteen
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP (vent/cor) [W/m^2]  \
# 54             12/1/2017  08:00                       125.6360
# 114            12/1/2017  09:00                       284.8100
# 174            12/1/2017  10:00                       402.9670
# 234            12/1/2017  11:00                       536.9720
# 294            12/1/2017  12:00                       320.2260
# ...                  ...    ...                            ...
# 548423        12/31/2019  12:00                       502.8150
# 548483        12/31/2019  13:00                       472.6210
# 548543        12/31/2019  14:00                       380.8030
# 548603        12/31/2019  15:00                       250.1740
# 548663        12/31/2019  16:00                        32.3216
#
#         Global LI-200 [W/m^2]  Global 40-South LI-200 [W/m^2]  \
# 54                    132.515                        409.0500
# 114                   284.529                        695.8350
# ...

# %%
nineteen
# Out:
#        DATE (MM/DD/YYYY)    MST  Global PSP (vent/cor) [W/m^2]  \
# 35              1/1/2020  08:00                        35.6229
# 95              1/1/2020  09:00                       109.4640
# 155             1/1/2020  10:00                       387.2590
# 215             1/1/2020  11:00                       151.6950
# 275             1/1/2020  12:00                        86.9186
# ...                  ...    ...                            ...
# 707260         8/16/2022  14:00                       243.1170
# 707320         8/16/2022  15:00                       190.5560
# 707380         8/16/2022  16:00                        82.6278
# 707440         8/16/2022  17:00                        56.4529
# 707500         8/16/2022  18:00                        23.5692
#
#         Global LI-200 [W/m^2]  Global 40-South LI-200R [W/m^2]  \
# 35                    27.5164                          30.3269
# 95                    95.3761                         208.2460
# ...

# %%
df = [two[['Global PSP [W/m^2]', 'time']], three[['Global PSP [W/m^2]', 'time']], four[['Global PSP [W/m^2]', 'time']], five[['Global PSP [W/m^2]', 'time']], six[['Global PSP [W/m^2]', 'time']], seven[['Global PSP [W/m^2]', 'time']], eight[['Global PSP [W/m^2]', 'time']], nine[['Global PSP [W/m^2]', 'time']], ten[['Global PSP [W/m^2]', 'time']], eleven[['Global PSP [W/m^2]', 'time']], twelve[['Global PSP [W/m^2]', 'time']], thirteen[['Global PSP [W/m^2]', 'time']], fourteen[['Global PSP [W/m^2]', 'time']]]
solarGPSP = pd.concat(df)

# %%
solarGPSP = solarGPSP[['Global PSP [W/m^2]', 'time']]

# %%
solarGPSP
# Out:
#         Global PSP [W/m^2]                time
# 0               -99999.000 1984-10-25 04:00:00
# 1               -99999.000 1984-10-25 05:00:00
# 2               -99999.000 1984-10-25 06:00:00
# 3               -99999.000 1984-10-25 07:00:00
# 4               -99999.000 1984-10-25 08:00:00
# ...                    ...                 ...
# 452650             381.910 2012-05-31 15:00:00
# 452710             674.460 2012-05-31 16:00:00
# 452770             231.210 2012-05-31 17:00:00
# 452830             193.820 2012-05-31 18:00:00
# 452890              13.435 2012-05-31 19:00:00
#
# [138427 rows x 2 columns]

# %%
solarGPSP = solarGPSP[solarGPSP['Global PSP [W/m^2]'] != -99999]

# %%
solarGPSP.reset_index(drop = True)
# Out:
#         Global PSP [W/m^2]                time
# 0                  355.000 1984-10-25 09:00:00
# 1                  500.000 1984-10-25 10:00:00
# 2                  601.000 1984-10-25 11:00:00
# 3                  638.000 1984-10-25 12:00:00
# 4                  624.000 1984-10-25 13:00:00
# ...                    ...                 ...
# 138207             381.910 2012-05-31 15:00:00
# 138208             674.460 2012-05-31 16:00:00
# 138209             231.210 2012-05-31 17:00:00
# 138210             193.820 2012-05-31 18:00:00
# 138211              13.435 2012-05-31 19:00:00
#
# [138212 rows x 2 columns]

# %%
df1 = [fifteen[['Global PSP (vent/cor) [W/m^2]', 'time']], sixteen[['Global PSP (vent/cor) [W/m^2]', 'time']], seventeen[['Global PSP (vent/cor) [W/m^2]', 'time']], eighteen[['Global PSP (vent/cor) [W/m^2]', 'time']], nineteen[['Global PSP (vent/cor) [W/m^2]', 'time']]]
solarGPSPC = pd.concat(df1)

# %%
solarGPSPC = solarGPSPC.rename(columns = {'Global PSP (vent/cor) [W/m^2]': 'Global PSP [W/m^2]'})

# %%
solarGPSPC
# Out:
#         Global PSP [W/m^2]                time
# 23                 52.1136 2012-06-01 05:00:00
# 83                247.6688 2012-06-01 06:00:00
# 143               243.3828 2012-06-01 07:00:00
# 203               574.9064 2012-06-01 08:00:00
# 263               791.2830 2012-06-01 09:00:00
# ...                    ...                 ...
# 707260            243.1170 2022-08-16 14:00:00
# 707320            190.5560 2022-08-16 15:00:00
# 707380             82.6278 2022-08-16 16:00:00
# 707440             56.4529 2022-08-16 17:00:00
# 707500             23.5692 2022-08-16 18:00:00
#
# [48037 rows x 2 columns]

# %%
df2 = [solarGPSP, solarGPSPC]
solar_complete = pd.concat(df2)

# %%
solar_complete = solar_complete[(solar_complete['Global PSP [W/m^2]'] != -99999) & (solar_complete['Global PSP [W/m^2]'] <= 3000)]
solar_complete.reset_index(drop = True)
# Out:
#         Global PSP [W/m^2]                time
# 0                 355.0000 1984-10-25 09:00:00
# 1                 500.0000 1984-10-25 10:00:00
# 2                 601.0000 1984-10-25 11:00:00
# 3                 638.0000 1984-10-25 12:00:00
# 4                 624.0000 1984-10-25 13:00:00
# ...                    ...                 ...
# 186241            243.1170 2022-08-16 14:00:00
# 186242            190.5560 2022-08-16 15:00:00
# 186243             82.6278 2022-08-16 16:00:00
# 186244             56.4529 2022-08-16 17:00:00
# 186245             23.5692 2022-08-16 18:00:00
#
# [186246 rows x 2 columns]

# %%
s = pd.to_datetime(min(solar_complete.time))
e = pd.to_datetime(max(solar_complete.time))
solar_complete['time'] = pd.to_datetime(solar_complete.time)
data_res = pd.DataFrame(pd.date_range(s, e, freq = 'H'), columns = ['time'])

# %%
data_joined = pd.merge(data_res, solar_complete, on=['time'], how = 'left')
data_joined.set_index('time').resample('1H').mean().interpolate()
# Out:
#                      Global PSP [W/m^2]
# time
# 1984-10-25 09:00:00            355.0000
# 1984-10-25 10:00:00            500.0000
# 1984-10-25 11:00:00            601.0000
# 1984-10-25 12:00:00            638.0000
# 1984-10-25 13:00:00            624.0000
# ...                                 ...
# 2022-08-16 14:00:00            243.1170
# 2022-08-16 15:00:00            190.5560
# 2022-08-16 16:00:00             82.6278
# 2022-08-16 17:00:00             56.4529
# 2022-08-16 18:00:00             23.5692
#
# [331426 rows x 1 columns]

# %%
data_joined.to_csv('/home/cyrus/Documents/Solar/cleaned_PSP_data.csv')

# %% [markdown]
# ## Discussion of everything done up until this point
#
# 1. The EDA was rather straighforward: simple table checking for a few different reasons
#     1. Identify the feature with the most entries, as this model only uses a single feature
#     2. Identify any obvious outliers
# 2. Outlier Handling: values = -999999 and values > 3000 were found to be from systemic issues with the data gathering equipment
# 3. Since there is only one feature needed per model, the EDA was ended after the feature identification, handling of the outliers, and combining the dataframes
# 4. Data Cleaning: on top of the already mentioned outlier handling, the time differences between all of the datasets included 1 hour, 5 minutes, and 1 minute intervals. I ensured that the data was all on the same time interval. Also, for missing data, I used a Interpolate Fill Resample method. The data is fitted between the final time value of one dataset, and the first time value of the other, and a point is added at the specified time interval (1H in this case)
# 5. Limitations of this model: I am assuming that 'Global PSP' (unvented) and 'Global PSP' (vent/cor) values are the same output, and therefore can be treated as 'continuous' of one another. However, considering that there is a decent chance I am wrong about this, I have followed up with the group that gathered the data for more information. The links containing the instrument specs I need to be sure are dead, and if they provide me with the information about the specs I need, updating the model will be super easy as I already have the formulas/process for the fix created
# 6. Future work (after PSP data) will include running other features through the same process and comparing the results, ensuring that 'Global PSP' vented/unvented can be treated as the same, and updating the model if it isn't. Another idea could be to ignore the hour-interval data, and work with 5 minute intervals, and compare the accuracy of the models then
#
# ### [Data was found here](https://midcdmz.nrel.gov/apps/day.pl?BMS)
# ### [Future instrumentation information will be found here](https://midcdmz.nrel.gov/apps/html.pl?site=BMS;page=instruments)
